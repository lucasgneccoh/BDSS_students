# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasgneccoh/BDSS_Dauphine/blob/main/BDSS_TD3_SAX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bases de données semi-structurées - TD 3
#
# Welcome to the TD 3. This part will cover SAX

# %% [markdown]
# ## Preambule

# %%
from lxml import etree
import re
from xml.dom.minidom import parse
import xml.sax

# Functions to work with XML files

def validate_xml(xml_path:str, dtd_path:str) -> bool:
    ''' Validate an XML file  against a DTD using the lxml library
    '''
    try:
        dtd = etree.DTD(open(dtd_path))
    except etree.DTDParseError as ed:
        print(f"DTDParseError: {ed}")
        for i, er in enumerate(ed.error_log):
            print(f"\t{i}-> {er.message}, at line {er.line}")
        etree.clear_error_log()
        return False

    try:
        xml_doc = etree.parse(xml_path)
    except etree.XMLSyntaxError as e:
        print(f"XMLSyntaxError: {e}")
        for i, er in enumerate(e.error_log):
            print(f"\t{i}-> {er.message}, at line {er.line}")
        etree.clear_error_log()
        return False

    result = dtd.validate(xml_doc)
    if not result: print(dtd.error_log[0])

    return result

def write_xml_dtd_files_from_strings(xml_strings, dtd_strings, identifiers = None):
    ''' Write a list of strings into files. This strings should be XML and DTD files
    '''

    # If single strings are given, encapsulate them in lists  
    if all(map(lambda o: isinstance(o, str), [xml_strings, dtd_strings])):
        xml_strings, dtd_strings = [xml_strings], [dtd_strings]

    if len(xml_strings) != len(dtd_strings):
        raise Exception("Different number of XML and DTD strings!")

    # If no identifiers are given, create default ones. This determines file names
    if identifiers is None:
        identifiers = [f"file_{i}" for i in range(len(xml_strings))]

    try:
        for x, d, id in zip(xml_strings, dtd_strings, identifiers):
            xml_path, dtd_path = f"{id}.xml", f"{id}.dtd" 
            with open(xml_path,"w") as f:
                f.write(x)
            with open(dtd_path,"w") as f:
                f.write(d)
    except Exception as e:
        print("Problems while writing XML and DTD files")
        raise e

    return identifiers



def test_validation(xml_string, dtd_string, validator):
    ''' Validate an XML document against a DTD, both given as strings
    '''
    # Write files
    write_xml_dtd_files_from_strings(xml_string, dtd_string, identifiers = ['temp'])
    
    # Validate
    return validator("temp.xml", "temp.dtd" )

def xpath_query_xml_string(xml_string, query_string):
    xml_path = "xml_doc.xml"
    with open(xml_path, "w") as f:
        # Remove all whitespaces to keep the 'real' text of each node
        f.write(re.sub(">[\s|\n]*<", "><", xml_string))
        f.close()
    xml_doc = etree.parse(xml_path)
    query = etree.XPath(query_string)
    return query(xml_doc)

def xpath_query_xml_file(xml_path, query_string):
    xml_doc = etree.parse(xml_path)
    query = etree.XPath(query_string)
    return query(xml_doc)


def print_xpath_query_results(results):
    print(f"Total results: {len(results)}")
    print("*"*20 + "\n")
    for e in results:
        try:        
            print(f"node tag: {e.tag}")
            print(f"node text: *{e.text}*")
            print(', '.join([f"{k} = {v}"for k, v in e.items()]))
            print("-"*20)
        except:
            print("--Except")
            print(e)

# %% [markdown]
# ## SAX
# Download the FILMS dataset

# %%
dtd_link = "https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/films.dtd"
xml_link = "https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/films.xml"

# !rm "./films.dtd"
# !rm "./films.xml"

# Download the imdb sample file
# !wget {dtd_link}
# !wget {xml_link}

# If the download fails, you will have to load the files into the Colab session. 
# Go to the Files section on the left panel

if validate_xml("films.xml", "films.dtd"):
    print("Files were downloaded correctly")
# Out:
# --2022-02-22 10:31:00--  https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/films.dtd
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 626 [text/plain]
# Saving to: ‘films.dtd’
#
# films.dtd           100%[===================>]     626  --.-KB/s    in 0s
#
# 2022-02-22 10:31:05 (23,9 MB/s) - ‘films.dtd’ saved [626/626]
#
# --2022-02-22 10:31:05--  https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/films.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43462 (42K) [text/plain]
# Saving to: ‘films.xml’
#
# films.xml           100%[===================>]  42,44K  --.-KB/s    in 0,004s
#
# 2022-02-22 10:31:05 (11,5 MB/s) - ‘films.xml’ saved [43462/43462]
#
# Files were downloaded correctly

# %% [markdown]
# ### Example 1: Print only certain elements

# %%
class PrinterContentHandler(xml.sax.ContentHandler):
    def __init__(self, tags_to_print = None):
        super().__init__()
        self.tags_to_print = tags_to_print
        

    def startElement(self, name, attrs):
        if not self.tags_to_print is None and name in self.tags_to_print:
            print("startElement: '" + name + "'")
        return

    def endElement(self, name):
        print("endElement: '" + name + "'\n")
        return

    def characters(self, content):
        # When text is encountered
        print("Characters: " + content + "")
        return


tags_to_print = ["FILM"]
handler = PrinterContentHandler(tags_to_print = tags_to_print)

path = "films.xml"
f = open(path)

xml.sax.parse(f, handler)
# Out:
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Vertigo
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: James
# endElement: 'PRENOM'
#
# Characters: Stewart
# endElement: 'NOM'
#
# Characters:
#
# Characters: John Ferguson
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Kim
# endElement: 'PRENOM'
#
# Characters: Novak
# endElement: 'NOM'
#
# Characters:
#
# Characters: Madeleine Elster
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Scottie Ferguson, ancien inspecteur de police, est sujet au vertige depuis qu'il a vu mourir son collègue. Elster, son ami, le charge de surveiller sa femme, Madeleine, ayant des tendances suicidaires. Amoureux de la jeune femme Scottie ne remarque pas le piège qui se trame autour de lui et dont il va être la victime...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Alien
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Sigourney
# endElement: 'PRENOM'
#
# Characters: Weaver
# endElement: 'NOM'
#
# Characters:
#
# Characters: Ripley
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Près d'un vaisseau spatial échoué sur une lointaine planète, des Terriens en mission découvrent de bien étranges "oeufs". Ils en ramènent un à bord, ignorant qu'ils viennent d'introduire parmi eux un huitième passager particulièrement féroce et meurtrier.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Titanic
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Kate
# endElement: 'PRENOM'
#
# Characters: Winslet
# endElement: 'NOM'
#
# Characters:
#
# Characters: Rose DeWitt Bukater
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Leonardo
# endElement: 'PRENOM'
#
# Characters: DiCaprio
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jack Dawson
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Conduite par Brock Lovett, une expédition américaine fouillant l'épave du Titanic remonte à la surface le croquis d'une femme nue. Alertée par les médias la dame en question, Rose DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du naufrage, d'où elle entreprend de conter le récit de son fascinant, étrange et tragique voyage...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Sacrifice
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Volte/Face
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: John
# endElement: 'PRENOM'
#
# Characters: Travolta
# endElement: 'NOM'
#
# Characters:
#
# Characters: Sean Archer/Castor Troy
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Nicolas
# endElement: 'PRENOM'
#
# Characters: Cage
# endElement: 'NOM'
#
# Characters:
#
# Characters: Castor Troy/Sean Archer
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Directeur d'une unité anti-terroriste, Sean Archer recherche Castor Troy, un criminel responsable de la mort de son fils six ans plus tôt. Il parvient à l'arrêter mais apprend que Troy a caché une bombe au Palais des Congrès de Los Angeles. Seul le frère de Troy peut la désamorcer et, pour l'approcher, Archer se fait greffer le visage de Troy.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Sleepy Hollow
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Fantastique
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Johnny
# endElement: 'PRENOM'
#
# Characters: Depp
# endElement: 'NOM'
#
# Characters:
#
# Characters: Constable Ichabod Crane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Christina
# endElement: 'PRENOM'
#
# Characters: Ricci
# endElement: 'NOM'
#
# Characters:
#
# Characters: Katrina Anne Van Tassel
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Christopher
# endElement: 'PRENOM'
#
# Characters: Walken
# endElement: 'NOM'
#
# Characters:
#
# Characters: Le cavalier
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Nouvelle Angleterre, 1799. A Sleepy Hollow, plusieurs cadavres sont retrouvés décapités. La rumeur attribue ces meurtres à un cavalier lui-même sans tête. Mais le fin limier new-yorkais Ichabod Crane ne croit pas en ses aberrations. Tombé sous le charme de la vénéneuse Katrina, il mène son enquête au coeur des sortilèges de Sleepy Hollow..
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: American Beauty
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Comédie
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Kevin
# endElement: 'PRENOM'
#
# Characters: Spacey
# endElement: 'NOM'
#
# Characters:
#
# Characters: Lester Burnham
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Anette
# endElement: 'PRENOM'
#
# Characters: Bening
# endElement: 'NOM'
#
# Characters:
#
# Characters: Carolyn Burnham
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Lester Burnham, sa femme Carolyn et leur fille Jane mènent apparemment une vie des plus heureuses dans leur belle banlieue. Mais derrière cette respectable façade se tisse une étrange et grinçante tragi-comédie familiale où désirs inavoués, frustrations et violences refoulées conduiront inexorablement un homme vers la mort.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Impitoyable
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Western
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Clint
# endElement: 'PRENOM'
#
# Characters: Eastwood
# endElement: 'NOM'
#
# Characters:
#
# Characters: William Munny
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Gene
# endElement: 'PRENOM'
#
# Characters: Hackman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Little Bill Dagget
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Morgan
# endElement: 'PRENOM'
#
# Characters: Freeman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Ned Logan
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Légendaire hors-la-loi, William Munny s'est reconverti depuis onze ans en paisible fermier. Il reprend néanmoins les armes pour traquer deux tueurs en compagnie de son vieil ami Ned Logan. Mais ce dernier est capturé, puis éxécute. L'honneur et l'amitié imposent dès lors à Munny de redevenir une dernière fois le héros qu'il fut jadis...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Gladiator
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Russell
# endElement: 'PRENOM'
#
# Characters: Crowe
# endElement: 'NOM'
#
# Characters:
#
# Characters: Maximus
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Le général romain Maximus est le plus fidèle soutien de l'empereur Marc Aurèle, qu'il a conduit de victoire en victoire avec une bravoure et un dévouement exemplaires. Jaloux du prestige de Maximus, et plus encore de l'amour que lui voue l'empereur, le fils de Marc-Aurèle, Commode, s'arroge brutalement le pouvoir, puis ordonne l'arrestation du général et son exécution. Maximus échappe à ses assassins mais ne peut empêcher le massacre de sa famille. Capturé par un marchand d'esclaves, il devient gladiateur et prépare sa vengeance.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Blade Runner
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Harrison
# endElement: 'PRENOM'
#
# Characters: Ford
# endElement: 'NOM'
#
# Characters:
#
# Characters: Deckard
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Rutger
# endElement: 'PRENOM'
#
# Characters: Hauer
# endElement: 'NOM'
#
# Characters:
#
# Characters: Batty
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: En 2019, lors de la décadence de Los Angeles, des êtres synthétiques, sans pensée, sans émotions, suffisent aux différents travaux d'entretien. Leur durée de vie n'excède pas 4 années. Un jour, ces ombres humaines se révoltent et on charge les tueurs, appelés Blade Runner, de les abattre...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Piège de cristal
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Bruce
# endElement: 'PRENOM'
#
# Characters: Willis
# endElement: 'NOM'
#
# Characters:
#
# Characters: McClane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: John Mc Clane, policier new-yorkais, vient passer Noel a Los Angeles aupres de sa femme. Dans le building ou elle travaille, il se retrouve temoin de la prise en otage de tout le personnel par 12 terroristes. Objectif de ces derniers, vider les coffres de la societe. Cache mais isole, il entreprend de prevenir l'exterieur...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: 58 minutes pour vivre
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Bruce
# endElement: 'PRENOM'
#
# Characters: Willis
# endElement: 'NOM'
#
# Characters:
#
# Characters: McLane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters:
#
# Characters: Venu attendre sa femme a l'aéroport, le policier John McClane remarque la présence de terroristes qui ont pris le contrôle des pistes, empêchant tout avion d'atterrir et menaçant de laisser les appareils en vol tourner jusqu'à épuisement de leur kérosène. John n'a devant lui que 58 minutes pour éviter la catastrophe...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Van Gogh
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Jacques
# endElement: 'PRENOM'
#
# Characters: Dutronc
# endElement: 'NOM'
#
# Characters:
#
# Characters: Van Gogh
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Les derniers jours de la vie de Vincent Van Gogh, réfugié à Auvers-sur-Oise, près de chez son ami et protecteur le docteur Gachet, un ami de son frère Théo. Ce peintre maudit, que les villageois surnommaient "le fou", n'avait alors plus que deux mois à vivre, qu'il passa en peignant un tableau par jour.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Seven
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Policier
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Kevin
# endElement: 'PRENOM'
#
# Characters: Spacey
# endElement: 'NOM'
#
# Characters:
#
# Characters: Doe
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Morgan
# endElement: 'PRENOM'
#
# Characters: Freeman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Somerset
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Brad
# endElement: 'PRENOM'
#
# Characters: Pitt
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mills
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: A New York, un criminel anonyme a décidé de commettre 7 meurtres basés sur les 7 pêchés capitaux énoncés dans la Bible : gourmandise, avarice, paresse, orgueil, luxure, envie et colère. Vieux flic blasé à 7 jours de la retraite, l'inspecteur Somerset mène l'enquête tout en formant son remplaçant, l'ambitieux inspecteur David Mills...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: L'armée des douze singes
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Bruce
# endElement: 'PRENOM'
#
# Characters: Willis
# endElement: 'NOM'
#
# Characters:
#
# Characters: Cole
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le nom de la rose
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Policier
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Sean
# endElement: 'PRENOM'
#
# Characters: Connery
# endElement: 'NOM'
#
# Characters:
#
# Characters: Baskerville
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Christian
# endElement: 'PRENOM'
#
# Characters: Slater
# endElement: 'NOM'
#
# Characters:
#
# Characters: de Melk
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: En l'an 1327, dans une abbaye bénédictine, le moine franciscain Guillaume de Baskerville, accompagné de son jeune novice Adso, enquête sur de mystérieuses morts qui frappent la confrérie. Le secret semble résider dans la bibliothèque, où le vieux Jorge garde jalousement un livre jugé maudit.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Pulp fiction
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: John
# endElement: 'PRENOM'
#
# Characters: Travolta
# endElement: 'NOM'
#
# Characters:
#
# Characters: Vincent Vega
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Bruce
# endElement: 'PRENOM'
#
# Characters: Willis
# endElement: 'NOM'
#
# Characters:
#
# Characters: Butch Coolidge
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Samuel L.
# endElement: 'PRENOM'
#
# Characters: Jackson
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jules Winnfield
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Rosanna
# endElement: 'PRENOM'
#
# Characters: Arquette
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jody
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Uma
# endElement: 'PRENOM'
#
# Characters: Thurman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mia Wallace
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Pulp Fiction décrit l'odyssée sanglante et burlesque de petits malfrats dans la jungle de Hollywood, ou s'entrecroisent les destins de deux petits tueurs, d'un dangereux gangster marié à une camée, d'un boxeur roublard, de prêteurs sur gages sadiques, d'un caïd élégant et dévoué, d'un dealer bon mari et de deux tourtereaux à la gachette facile...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Mary à tout prix
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Comédie
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Cameron
# endElement: 'PRENOM'
#
# Characters: Diaz
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mary Jensen Matthews
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Mat
# endElement: 'PRENOM'
#
# Characters: Dillon
# endElement: 'NOM'
#
# Characters:
#
# Characters: Pat Healy
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Pour retrouver l'amour de sa jeunesse, la belle Mary, Ted-le-looser engage Pat Healy, un privé. Subjugé par la jeune femme, ce dernier tente de la séduire en se faisant passer pour un architecte. Il cache la vérité à Ted et fait cause commune avec Tucker, un autre prétendant, pour se débarrasser de l'encombrant Ted...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Terminator
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Arnold
# endElement: 'PRENOM'
#
# Characters: Schwartzenegger
# endElement: 'NOM'
#
# Characters:
#
# Characters: Terminator
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Deux creatures venues du futur debarquent sur terre. L'une d'entre elles, le Terminator, doit eliminer une certaine Sarah Connor, qui doit enfanter celui qui sera le chef d'un groupe de resistants. L'autre, Kyle Reese, est charge par les rebelles de defendre Sarah...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Les dents de la mer
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Horreur
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Roy
# endElement: 'PRENOM'
#
# Characters: Sheider
# endElement: 'NOM'
#
# Characters:
#
# Characters: Martin Brody
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Robert
# endElement: 'PRENOM'
#
# Characters: Shaw
# endElement: 'NOM'
#
# Characters:
#
# Characters: Quint
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Richard
# endElement: 'PRENOM'
#
# Characters: Dreyfus
# endElement: 'NOM'
#
# Characters:
#
# Characters: Matt Hooper
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Dans la station balnéaire d'Amityville, un requin géant frappe à plusieurs reprises. Soucieux d'une bonne saison touristique, le maire interdit au sherif Brody de fermer les plages. Une prime est offerte et le célèbre chasseur de requin Quint se lance avec Brody et l'ichtyologue Hooper à la poursuite du monstre...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le silence des agneaux
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Policier
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Anthony
# endElement: 'PRENOM'
#
# Characters: Hopkins
# endElement: 'NOM'
#
# Characters:
#
# Characters: Dr. Hannibal Lecter
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jodie
# endElement: 'PRENOM'
#
# Characters: Foster
# endElement: 'NOM'
#
# Characters:
#
# Characters: Clarice Starling
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Afin de retrouver la piste d'un tueur surnommé Buffalo Bill car il scalpe les femmes qu'il assassine, la jeune stagiaire du FBI Clarice Starling est dépêchée auprès d'Hannibal Lecter, prisonnier pour avoir dévoré ses victimes. La coopération de ce dernier devrait permettre à Clarice de saisir et d'anticiper le comportement de Buffalo...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le prince d'Egypte
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Dessin animé
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Val
# endElement: 'PRENOM'
#
# Characters: Kilmer
# endElement: 'NOM'
#
# Characters:
#
# Characters: Moise
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Ralph
# endElement: 'PRENOM'
#
# Characters: Fiennes
# endElement: 'NOM'
#
# Characters:
#
# Characters: Ramses
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Michelle
# endElement: 'PRENOM'
#
# Characters: Pfeiffer
# endElement: 'NOM'
#
# Characters:
#
# Characters:
#
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Sandra
# endElement: 'PRENOM'
#
# Characters: Bullock
# endElement: 'NOM'
#
# Characters:
#
# Characters: Miriam
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jeff
# endElement: 'PRENOM'
#
# Characters: Goldblum
# endElement: 'NOM'
#
# Characters:
#
# Characters: Aaron
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Godzilla
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Matthew
# endElement: 'PRENOM'
#
# Characters: Broderick
# endElement: 'NOM'
#
# Characters:
#
# Characters: Dr. Nikos Tatopoulos
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jean
# endElement: 'PRENOM'
#
# Characters: Reno
# endElement: 'NOM'
#
# Characters:
#
# Characters: Philippe Roaché
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Issu des radiations atomiques engendrées par les essais nucléaires en Polynésie, un monstre gigantesque, aussi haut qu'un building, se dirige vers New York, semant le chaos sur son passage. Pour tenter de stopper cette créature destructrice, l'armée s'associe à une équipe de scientifiques américains et à un énigmatique enquêteur français...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Matrix
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Keanu
# endElement: 'PRENOM'
#
# Characters: Reeves
# endElement: 'NOM'
#
# Characters:
#
# Characters: Neo
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Laurence
# endElement: 'PRENOM'
#
# Characters: Fishburne
# endElement: 'NOM'
#
# Characters:
#
# Characters: Morpheus
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Dans un monde où tout ce qui semble réel est en fait élaboré par l'univers électronique baptisé la Matrice, Néo, un programmeur, est contacté par un certain Morpheus. D'après lui, Néo serait le Libérateur tant attendu, le seul capable de mettre en échec l'omnipotence de la Matrice et rendre ses droits à la réalité...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Mission: Impossible
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Jean
# endElement: 'PRENOM'
#
# Characters: Reno
# endElement: 'NOM'
#
# Characters:
#
# Characters: Franz Krieger
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tom
# endElement: 'PRENOM'
#
# Characters: Cruise
# endElement: 'NOM'
#
# Characters:
#
# Characters: Ethan Hunt
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: John
# endElement: 'PRENOM'
#
# Characters: Voight
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jim Phelps
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Emmanuelle
# endElement: 'PRENOM'
#
# Characters: Béart
# endElement: 'NOM'
#
# Characters:
#
# Characters: Claire Phelps
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Chargé d'une nouvelle mission, l'agent du contre espionnage Ethan Hunt tombe avec son équipe dans un piège sanglant. Seul survivant avec Claire, la jeune épouse de son regretté chef Jim Phelps, Ethan se retrouve accusé de trahison. En fuite, il prépare sa contre-attaque, recrutant l'homme de main Krieger et le pirate informatique Luther...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Kagemusha
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Guerre
# endElement: 'GENRE'
#
# Characters: JP
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Au XVIe siecle, Takeda, grand seigneur trouble par les guerres civiles de son pays, fait appel a un Kagemusha pour l'aider dans ses batailles. Takeda est blesse et avant de mourir, il exige que sa mort soit tenue secrete pendant trois ans afin d'eviter un eclatement du clan. Le Kagemusha devra le remplacer...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Les pleins pouvoirs
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Policier
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Clint
# endElement: 'PRENOM'
#
# Characters: Eastwood
# endElement: 'NOM'
#
# Characters:
#
# Characters: Luther Whitney
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Gene
# endElement: 'PRENOM'
#
# Characters: Hackman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Le président Richmond
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Ed
# endElement: 'PRENOM'
#
# Characters: Harris
# endElement: 'NOM'
#
# Characters:
#
# Characters: Seth Frank
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Luther Whitney est l'as des cambrioleurs. Occupé à vider le coffre de l'influent Walter Sullivan, il est témoin d'un meurtre sadique impliquant le Président des Etats-Unis et les services secrets. Soupçonné par la police d'en être l'auteur, il se retrouve également traqué par les tueurs, qui ont compris qu'ils ont été observés.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le gendarme et les extra-terrestres
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Comédie
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Louis
# endElement: 'PRENOM'
#
# Characters: De Funès
# endElement: 'NOM'
#
# Characters:
#
# Characters: Inspecteur Cruchot
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Michel
# endElement: 'PRENOM'
#
# Characters: Galabru
# endElement: 'NOM'
#
# Characters:
#
# Characters: Adjudant Gerber
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Les frères pétards
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Comédie
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Michel
# endElement: 'PRENOM'
#
# Characters: Galabru
# endElement: 'NOM'
#
# Characters:
#
# Characters: Momo's Father
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Josiane
# endElement: 'PRENOM'
#
# Characters: Balasko
# endElement: 'NOM'
#
# Characters:
#
# Characters: Aline
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Dominique
# endElement: 'PRENOM'
#
# Characters: Lavanant
# endElement: 'NOM'
#
# Characters:
#
# Characters: Une policière
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Gérard
# endElement: 'PRENOM'
#
# Characters: Lanvin
# endElement: 'NOM'
#
# Characters:
#
# Characters: Manu
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jacques
# endElement: 'PRENOM'
#
# Characters: Villeret
# endElement: 'NOM'
#
# Characters:
#
# Characters: Momo
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le monde perdu
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Horreur
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Jeff
# endElement: 'PRENOM'
#
# Characters: Goldblum
# endElement: 'NOM'
#
# Characters:
#
# Characters: Dr. Ian Malcolm
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Rain Man
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Tom
# endElement: 'PRENOM'
#
# Characters: Cruise
# endElement: 'NOM'
#
# Characters:
#
# Characters: Charlie Babbitt
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Dustin
# endElement: 'PRENOM'
#
# Characters: Hoffman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Raymond Babbitt
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: A la mort de son père, Charlie se voit déposséder de son héritage par un frère dont il ignorait l'existence, Raymond. Celui-ci est autiste et vit dans un hôpital psychiatrique. Charlie enlève Raymond afin de prouver qu'il est capable de s'en occuper et de toucher l'héritage.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Top Gun
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Val
# endElement: 'PRENOM'
#
# Characters: Kilmer
# endElement: 'NOM'
#
# Characters:
#
# Characters: Iceman
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tom
# endElement: 'PRENOM'
#
# Characters: Cruise
# endElement: 'NOM'
#
# Characters:
#
# Characters: Lt. Pete 'Maverick' Mitchell
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Kelly
# endElement: 'PRENOM'
#
# Characters: McGillis
# endElement: 'NOM'
#
# Characters:
#
# Characters: Charlotte Blackwood
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters:
#
# Characters: Pilote de chasse émérite mais casse-cou Maverick Mitchell est admis à Top Gun, l'école de l'élite de l'aéronavale. Son manque de prudence lui attire les foudres de ses supérieurs et la haine de certains coéquipiers. Il perd subitement la foi et confiance en lui quand son ami de toujours meurt en vol et qu'il s'en croit responsable...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Les bronzés font du ski
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Comédie
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Josiane
# endElement: 'PRENOM'
#
# Characters: Balasko
# endElement: 'NOM'
#
# Characters:
#
# Characters: Nathalie Morin
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Dominique
# endElement: 'PRENOM'
#
# Characters: Lavanant
# endElement: 'NOM'
#
# Characters:
#
# Characters: Christiane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Michel
# endElement: 'PRENOM'
#
# Characters: Blanc
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jean-Claude Dus
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Christian
# endElement: 'PRENOM'
#
# Characters: Clavier
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jérôme
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Thierry
# endElement: 'PRENOM'
#
# Characters: Lhermite
# endElement: 'NOM'
#
# Characters:
#
# Characters: Popeye
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Apres avoir passe des vacances d'ete ensemble, Bernard, Nathalie, Gigi, Jerome, Popeye, Jean-Claude et Christiane se retrouvent aux sports d'hiver. Tous ont leurs problemes de coeur ou d'argent, mais il faut bien vivre avec. Avant de se separer, se perdre dans la montagne leur permet de gouter aux joies de la "vraie vie" paysanne...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: MICROCOSMOS
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Documentaire
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters:
# Characters:
#
# Characters: Une heure quinze sur une planète inconnue : la Terre, redécouverte à l'echelle du centimètre. Ses habitants, des créatures fantastiques : les insectes et autres animaux de l'herbe et de l'eau. Ses paysages : les forêts impenétrables que sont les touffes d'herbe, ou des gouttes de rosée grosses comme des ballons...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Psychose
# endElement: 'TITRE'
#
# Characters:
#
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Anthony
# endElement: 'PRENOM'
#
# Characters: Perkins
# endElement: 'NOM'
#
# Characters:
#
# Characters: Norman Bates
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Vera
# endElement: 'PRENOM'
#
# Characters: Miles
# endElement: 'NOM'
#
# Characters:
#
# Characters: Lila Crane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Janet
# endElement: 'PRENOM'
#
# Characters: Leigh
# endElement: 'NOM'
#
# Characters:
#
# Characters: Marion Crane
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Après avoir volé 40 000 dollars, Marion Crane se rend dans un motel tenu par Norman Bates. Elle est poignardée sous sa douche par une femme. Norman fait disparaitre le corps et les affaires de la jeune femme. Mais Sam, le fiancé de Marion, inquiet de ne pas avoir de nouvelles, engage un détective pour la retrouver...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le retour du Jedi
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Harrison
# endElement: 'PRENOM'
#
# Characters: Ford
# endElement: 'NOM'
#
# Characters:
#
# Characters: Han Solo
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Mark
# endElement: 'PRENOM'
#
# Characters: Hamill
# endElement: 'NOM'
#
# Characters:
#
# Characters: Luke Skywalker
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Carrie
# endElement: 'PRENOM'
#
# Characters: Fisher
# endElement: 'NOM'
#
# Characters:
#
# Characters: Princesse Leia
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Luke Skywalker s'introduit chez Jabba pour delivrer Han Solo et la princesse Leia, tandis que l'Empire reconstruit une deuxieme "Etoile de la Mort". Luke se rend ensuite au chevet de Yoda qui est mourant. Il lui apprend que Leia est sa soeur. Luke forme un commando pour attaquer l'Etoile, tandis qu'il affronte son pere, Darth Vador...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Les oiseaux
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Horreur
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Rod
# endElement: 'PRENOM'
#
# Characters: Taylor
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mitch Brenner
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tippi
# endElement: 'PRENOM'
#
# Characters: Hedren
# endElement: 'NOM'
#
# Characters:
#
# Characters: Melanie Daniels
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Melanie Daniels se rend à Bodega Bay pour offrir deux perruches en cage à Cathy, la soeur de l'avocat Mitch Brenner. Attaquée par une mouette, Melanie reste chez les Brenner pour la nuit. Mais d'autres évènements étranges se produisent: des enfants sont blessés par des corbeaux et la maison de Mitch est envahie par des milliers d'oiseaux.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Reservoir dogs
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Policier
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Quentin
# endElement: 'PRENOM'
#
# Characters: Tarantino
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mr. Brown
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Harvey
# endElement: 'PRENOM'
#
# Characters: Keitel
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mr. White/Larry
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tim
# endElement: 'PRENOM'
#
# Characters: Roth
# endElement: 'NOM'
#
# Characters:
#
# Characters: Freddy Newendyke/Mr. Orange
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Chris
# endElement: 'PRENOM'
#
# Characters: Penn
# endElement: 'NOM'
#
# Characters:
#
# Characters: Nice Guy Eddie
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters:
#
# Characters:  Voleurs de profession, Joe Cabot et son fils Eddie engagent un groupe de six criminels pour le cambriolage d'un diamantaire. Malgré toutes les précautions prises, la police est sur place le jour J, et l'opération se solde par un massacre. Les survivants du gang se réunissent pour règler leurs comptes, chacun soupçonnant l'autre d'avoir trahi.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Eyes Wide Shut
# endElement: 'TITRE'
#
# Characters:
#
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Tom
# endElement: 'PRENOM'
#
# Characters: Cruise
# endElement: 'NOM'
#
# Characters:
#
# Characters: Docteur William "Bill" Harford
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Nicole
# endElement: 'PRENOM'
#
# Characters: Kidman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Alice Harford
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Un couple de bourgeois, cédant à la jalousie et à l'obsession sexuelle, entreprend un voyage psychologique à la recherche de son identité. Le mari, au bout de son périple nocturne, revenu de ses désirs, ne trouvera finalement auprès de son épouse qu'un compromis banal mais complice, les yeux ouverts à tout jamais sur un rêve impossible.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Shining
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Horreur
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Jack
# endElement: 'PRENOM'
#
# Characters: Nicholson
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jack Torrance
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Jack Torrance s'installe avec sa femme et son fils Danny dans un hôtel fermé à la morte saison afin d'écrire un roman. Il apprend que le gardien précédent a tué sa femme et ses deux filles avant de se suicider. Très vite, Jack va s'apercevoir que des choses étranges se passent autour de lui et que son fils a des pouvoirs extrasensoriels...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Pas de printemps pour Marnie
# endElement: 'TITRE'
#
# Characters:
#
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Sean
# endElement: 'PRENOM'
#
# Characters: Connery
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mark R
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tippi
# endElement: 'PRENOM'
#
# Characters: Hedren
# endElement: 'NOM'
#
# Characters:
#
# Characters: Marnie Edgar
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Marnie est engagée comme secrétaire chez un editeur, Mark Rutland. Celui-ci amoureux d'elle, découvre qu'elle est kleptomane et l'oblige à l'épouser en la menaçant de la dénoncer. En s'apercevant que Marnie a la phobie de la cou leur rouge, Mark tente de remonter dans le passé de la jeune femme afin de comprendre les raisons de sa névrose.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Fenêtre sur cour
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Suspense
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: En repos forcé à cause d'une jambe plâtrée, le reporter L.B. Jefferies observe au téléobjectif les voisins de l'immeuble d'en face. C'est ainsi qu'il remarque le curieux manège d'un représentant de commerce, M. Thorwald, qu'il soupconne très vite d'avoir assassiné sa femme...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: La mort aux trousses
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Suspense
# endElement: 'GENRE'
#
# Characters: USA
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Cary
# endElement: 'PRENOM'
#
# Characters: Grant
# endElement: 'NOM'
#
# Characters:
#
# Characters: Roger O. Thornhill
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Eva Marie
# endElement: 'PRENOM'
#
# Characters: Saint
# endElement: 'NOM'
#
# Characters:
#
# Characters: Eve Kendall
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: James
# endElement: 'PRENOM'
#
# Characters: Mason
# endElement: 'NOM'
#
# Characters:
#
# Characters: Philipp Vandamm
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Roger Thornhill, publiciste, est pris dans le hall de son hôtel pour un certain Kaplan, un espion. Deux hommes tentent de le tuer et quand il retrouve l'un de ses agresseurs, celui-ci est assassiné devant ses yeux. Pris pour un meurtrier, il est obligé de fuir vers Chicago...
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Jeanne d'Arc
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Guerre
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Dustin
# endElement: 'PRENOM'
#
# Characters: Hoffman
# endElement: 'NOM'
#
# Characters:
#
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Milla
# endElement: 'PRENOM'
#
# Characters: Jovovich
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jeanne d'Arc
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Fane
# endElement: 'PRENOM'
#
# Characters: Dunaway
# endElement: 'NOM'
#
# Characters:
#
# Characters: Yolande d'Aragon
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: John
# endElement: 'PRENOM'
#
# Characters: Malkovitch
# endElement: 'NOM'
#
# Characters:
#
# Characters: Charles VII
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Tchéky
# endElement: 'PRENOM'
#
# Characters: Karyo
# endElement: 'NOM'
#
# Characters:
#
# Characters: Dunois
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le cinquième élément
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Science-fiction
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Bruce
# endElement: 'PRENOM'
#
# Characters: Willis
# endElement: 'NOM'
#
# Characters:
#
# Characters: Major Korben Dalla
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Milla
# endElement: 'PRENOM'
#
# Characters: Jovovich
# endElement: 'NOM'
#
# Characters:
#
# Characters: Leeloo
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Gary
# endElement: 'PRENOM'
#
# Characters: Oldman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jean-Baptiste Emmanuel Zorg
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Ian
# endElement: 'PRENOM'
#
# Characters: Holm
# endElement: 'NOM'
#
# Characters:
#
# Characters: Vito Cornelius
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Au XXIIIème siècle, dans un univers étrange et coloré, où tout espoir de survie est impossible sans la découverte du Cinquième Elément, un héros peu ordinaire affronte le mal pour sauver l'humanité.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Léon
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Action
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Jean
# endElement: 'PRENOM'
#
# Characters: Reno
# endElement: 'NOM'
#
# Characters:
#
# Characters: Léon
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Gary
# endElement: 'PRENOM'
#
# Characters: Oldman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Norman Stansfield
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Natalie
# endElement: 'PRENOM'
#
# Characters: Portman
# endElement: 'NOM'
#
# Characters:
#
# Characters: Mathilda
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: "Léon est un tueur. Un de la pire espèce. Il est introuvable, indétectable, pire qu'un sous-marin. Son ombre est comme une menace de danger permanent sur New York. Indestructible Léon ? Oui, jusqu'à ce qu'une petite souris pénètre son univers. Une toute petite souris aux yeux immenses..."
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Nikita
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Thriller
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Tchéky
# endElement: 'PRENOM'
#
# Characters: Karyo
# endElement: 'NOM'
#
# Characters:
#
# Characters: Bob
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Anne
# endElement: 'PRENOM'
#
# Characters: Parillaud
# endElement: 'NOM'
#
# Characters:
#
# Characters: Nikita
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jean-Hughes
# endElement: 'PRENOM'
#
# Characters: Anglade
# endElement: 'NOM'
#
# Characters:
#
# Characters: Marco
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Nikita, droguée et violente, est prise en mains par des psychiatres qui la rééduquent, la conditionnent, afin d'en faire une tueuse à la botte des Services Secrets. Plus tard, réalisant ce qu'elle est devenue, un pion sans vie privée que l'on manipule, elle tente d'échapper à ses commanditaires.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# startElement: 'FILM'
# Characters:
#
# Characters: Le grand bleu
# endElement: 'TITRE'
#
# Characters:
#
# Characters: Drame
# endElement: 'GENRE'
#
# Characters: FR
# endElement: 'PAYS'
#
# endElement: 'MES'
#
# Characters:
#
# Characters:
#
# Characters: Rosanna
# endElement: 'PRENOM'
#
# Characters: Arquette
# endElement: 'NOM'
#
# Characters:
#
# Characters: Johanna
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jean
# endElement: 'PRENOM'
#
# Characters: Reno
# endElement: 'NOM'
#
# Characters:
#
# Characters: Enzo Molinari
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# Characters: Jean-Marc
# endElement: 'PRENOM'
#
# Characters: Barr
# endElement: 'NOM'
#
# Characters:
#
# Characters: Jacques Mayol
# endElement: 'INTITULE'
#
# endElement: 'ROLE'
#
# endElement: 'ROLES'
#
# Characters:
#
# Characters: Jacques Mayol et Enzo Molinari se connaissent depuis l'enfance. Tous deux experts en apnée, s'affrontent continuellement pour obtenir le record du monde de plongée. Toujours en rivalité, les deux hommes descendent de plus en plus profond, au risque de leurs vies. Le film est ressorti en janvier 89 en version longue d'une durée de 2h40.
# endElement: 'RESUME'
#
# Characters:
#
# endElement: 'FILM'
#
# Characters:
#
# Characters: Cameron
# endElement: 'ACTNOM'
#
# Characters: James
# endElement: 'ACTPNOM'
#
# Characters: 1954
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hitchcock
# endElement: 'ACTNOM'
#
# Characters: Alfred
# endElement: 'ACTPNOM'
#
# Characters: 1899
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Scott
# endElement: 'ACTNOM'
#
# Characters: Ridley
# endElement: 'ACTPNOM'
#
# Characters: 1937
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Weaver
# endElement: 'ACTNOM'
#
# Characters: Sigourney
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Winslett
# endElement: 'ACTNOM'
#
# Characters: Kate
# ...
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Eastwood
# endElement: 'ACTNOM'
#
# Characters: Clint
# endElement: 'ACTPNOM'
#
# Characters: 1930
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hackman
# endElement: 'ACTNOM'
#
# Characters: Gene
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Freeman
# endElement: 'ACTNOM'
#
# Characters: Morgan
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Crowe
# endElement: 'ACTNOM'
#
# Characters: Russell
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Ford
# endElement: 'ACTNOM'
#
# Characters: Harrison
# endElement: 'ACTPNOM'
#
# Characters: 1942
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hauer
# endElement: 'ACTNOM'
#
# Characters: Rutger
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: McTierman
# endElement: 'ACTNOM'
#
# Characters: John
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Willis
# endElement: 'ACTNOM'
#
# Characters: Bruce
# endElement: 'ACTPNOM'
#
# Characters: 1955
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Harlin
# endElement: 'ACTNOM'
#
# Characters: Renny
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Pialat
# endElement: 'ACTNOM'
#
# Characters: Maurice
# endElement: 'ACTPNOM'
#
# Characters: 1925
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Dutronc
# endElement: 'ACTNOM'
#
# Characters: Jacques
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Fincher
# endElement: 'ACTNOM'
#
# Characters: David
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Pitt
# endElement: 'ACTNOM'
#
# Characters: Brad
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Gilliam
# endElement: 'ACTNOM'
#
# Characters: Terry
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Annaud
# endElement: 'ACTNOM'
#
# Characters: Jean-Jacques
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Connery
# endElement: 'ACTNOM'
#
# Characters: Sean
# endElement: 'ACTPNOM'
#
# Characters: 1930
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Slater
# endElement: 'ACTNOM'
#
# Characters: Christian
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Tarantino
# endElement: 'ACTNOM'
#
# Characters: Quentin
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Jackson
# endElement: 'ACTNOM'
#
# Characters: Samuel L.
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Arquette
# endElement: 'ACTNOM'
#
# Characters: Rosanna
# endElement: 'ACTPNOM'
#
# Characters: 1959
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Thurman
# endElement: 'ACTNOM'
#
# Characters: Uma
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Farrelly
# endElement: 'ACTNOM'
#
# Characters: Bobby
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Diaz
# endElement: 'ACTNOM'
#
# Characters: Cameron
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Dillon
# endElement: 'ACTNOM'
#
# Characters: Mat
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Schwartzenegger
# endElement: 'ACTNOM'
#
# Characters: Arnold
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Spielberg
# endElement: 'ACTNOM'
#
# Characters: Steven
# endElement: 'ACTPNOM'
#
# Characters: 1946
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Sheider
# endElement: 'ACTNOM'
#
# Characters: Roy
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Shaw
# endElement: 'ACTNOM'
#
# Characters: Robert
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Dreyfus
# endElement: 'ACTNOM'
#
# Characters: Richard
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Demme
# endElement: 'ACTNOM'
#
# Characters: Jonathan
# endElement: 'ACTPNOM'
#
# Characters: 1944
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hopkins
# endElement: 'ACTNOM'
#
# Characters: Anthony
# endElement: 'ACTPNOM'
#
# Characters: 1937
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Foster
# endElement: 'ACTNOM'
#
# Characters: Jodie
# endElement: 'ACTPNOM'
#
# Characters: 1962
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Chapman
# endElement: 'ACTNOM'
#
# Characters: Brenda
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Kilmer
# endElement: 'ACTNOM'
#
# Characters: Val
# endElement: 'ACTPNOM'
#
# Characters: 1959
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Fiennes
# endElement: 'ACTNOM'
#
# Characters: Ralph
# endElement: 'ACTPNOM'
#
# Characters: 1962
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Pfeiffer
# endElement: 'ACTNOM'
#
# Characters: Michelle
# endElement: 'ACTPNOM'
#
# Characters: 1957
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Bullock
# endElement: 'ACTNOM'
#
# Characters: Sandra
# endElement: 'ACTPNOM'
#
# Characters: 1964
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Goldblum
# endElement: 'ACTNOM'
#
# Characters: Jeff
# endElement: 'ACTPNOM'
#
# Characters: 1952
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Emmerich
# endElement: 'ACTNOM'
#
# Characters: Roland
# endElement: 'ACTPNOM'
#
# Characters: 1955
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Broderick
# endElement: 'ACTNOM'
#
# Characters: Matthew
# endElement: 'ACTPNOM'
#
# Characters: 1962
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Reno
# endElement: 'ACTNOM'
#
# Characters: Jean
# endElement: 'ACTPNOM'
#
# Characters: 1948
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Wachowski
# endElement: 'ACTNOM'
#
# Characters: Andy
# endElement: 'ACTPNOM'
#
# Characters: 1967
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Reeves
# endElement: 'ACTNOM'
#
# Characters: Keanu
# endElement: 'ACTPNOM'
#
# Characters: 1964
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Fishburne
# endElement: 'ACTNOM'
#
# Characters: Laurence
# endElement: 'ACTPNOM'
#
# Characters: 1961
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: De Palma
# endElement: 'ACTNOM'
#
# Characters: Brian
# endElement: 'ACTPNOM'
#
# Characters: 1940
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Cruise
# endElement: 'ACTNOM'
#
# Characters: Tom
# endElement: 'ACTPNOM'
#
# Characters: 1962
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Voight
# endElement: 'ACTNOM'
#
# Characters: John
# endElement: 'ACTPNOM'
#
# Characters: 1938
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Béart
# endElement: 'ACTNOM'
#
# Characters: Emmanuelle
# endElement: 'ACTPNOM'
#
# Characters: 1965
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Kurozawa
# endElement: 'ACTNOM'
#
# Characters: Akira
# endElement: 'ACTPNOM'
#
# Characters: 1910
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Harris
# endElement: 'ACTNOM'
#
# Characters: Ed
# endElement: 'ACTPNOM'
#
# Characters: 1950
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Linney
# endElement: 'ACTNOM'
#
# Characters: Laura
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Girault
# endElement: 'ACTNOM'
#
# Characters: Jean
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: De Funès
# endElement: 'ACTNOM'
#
# Characters: Louis
# endElement: 'ACTPNOM'
#
# Characters: 1914
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Galabru
# endElement: 'ACTNOM'
#
# Characters: Michel
# endElement: 'ACTPNOM'
#
# Characters: 1922
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Palud
# endElement: 'ACTNOM'
#
# Characters: Hervé
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Balasko
# endElement: 'ACTNOM'
#
# Characters: Josiane
# endElement: 'ACTPNOM'
#
# Characters: 1950
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Lavanant
# endElement: 'ACTNOM'
#
# Characters: Dominique
# endElement: 'ACTPNOM'
#
# Characters: 1944
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Lanvin
# endElement: 'ACTNOM'
#
# Characters: Gérard
# endElement: 'ACTPNOM'
#
# Characters: 1950
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Villeret
# endElement: 'ACTNOM'
#
# Characters: Jacques
# endElement: 'ACTPNOM'
#
# Characters: 1951
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Levinson
# endElement: 'ACTNOM'
#
# Characters: Barry
# endElement: 'ACTPNOM'
#
# Characters: 1942
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hoffman
# endElement: 'ACTNOM'
#
# Characters: Dustin
# endElement: 'ACTPNOM'
#
# Characters: 1937
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Scott
# endElement: 'ACTNOM'
#
# Characters: Tony
# endElement: 'ACTPNOM'
#
# Characters: 1944
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: McGillis
# endElement: 'ACTNOM'
#
# Characters: Kelly
# endElement: 'ACTPNOM'
#
# Characters: 1957
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Leconte
# endElement: 'ACTNOM'
#
# Characters: Patrice
# endElement: 'ACTPNOM'
#
# Characters: 1947
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Blanc
# endElement: 'ACTNOM'
#
# Characters: Michel
# endElement: 'ACTPNOM'
#
# Characters: 1952
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Clavier
# endElement: 'ACTNOM'
#
# Characters: Christian
# endElement: 'ACTPNOM'
#
# Characters: 1952
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Lhermite
# endElement: 'ACTNOM'
#
# Characters: Thierry
# endElement: 'ACTPNOM'
#
# Characters: 1952
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Pernnou
# endElement: 'ACTNOM'
#
# Characters: Marie
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Perkins
# endElement: 'ACTNOM'
#
# Characters: Anthony
# endElement: 'ACTPNOM'
#
# Characters: 1932
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Miles
# endElement: 'ACTNOM'
#
# Characters: Vera
# endElement: 'ACTPNOM'
#
# Characters: 1929
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Leigh
# endElement: 'ACTNOM'
#
# Characters: Janet
# endElement: 'ACTPNOM'
#
# Characters: 1927
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Marquand
# endElement: 'ACTNOM'
#
# Characters: Richard
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hamill
# endElement: 'ACTNOM'
#
# Characters: Mark
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Fisher
# endElement: 'ACTNOM'
#
# Characters: Carrie
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Taylor
# endElement: 'ACTNOM'
#
# Characters: Rod
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Hedren
# endElement: 'ACTNOM'
#
# Characters: Tippi
# endElement: 'ACTPNOM'
#
# Characters: 1931
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Ricci
# endElement: 'ACTNOM'
#
# Characters: Christina
# endElement: 'ACTPNOM'
#
# Characters: 1980
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Walken
# endElement: 'ACTNOM'
#
# Characters: Christopher
# endElement: 'ACTPNOM'
#
# Characters: 1943
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Keitel
# endElement: 'ACTNOM'
#
# Characters: Harvey
# endElement: 'ACTPNOM'
#
# Characters: 1939
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Roth
# endElement: 'ACTNOM'
#
# Characters: Tim
# endElement: 'ACTPNOM'
#
# Characters: 1961
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Penn
# endElement: 'ACTNOM'
#
# Characters: Chris
# endElement: 'ACTPNOM'
#
# Characters: 1966
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Kubrick
# endElement: 'ACTNOM'
#
# Characters: Stanley
# endElement: 'ACTPNOM'
#
# Characters: 1928
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Kidman
# endElement: 'ACTNOM'
#
# Characters: Nicole
# endElement: 'ACTPNOM'
#
# Characters: 1967
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Nicholson
# endElement: 'ACTNOM'
#
# Characters: Jack
# endElement: 'ACTPNOM'
#
# Characters: 1937
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Kelly
# endElement: 'ACTNOM'
#
# Characters: Grace
# endElement: 'ACTPNOM'
#
# Characters: 1929
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Grant
# endElement: 'ACTNOM'
#
# Characters: Cary
# endElement: 'ACTPNOM'
#
# Characters: 1904
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Saint
# endElement: 'ACTNOM'
#
# Characters: Eva Marie
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Mason
# endElement: 'ACTNOM'
#
# Characters: James
# endElement: 'ACTPNOM'
#
# Characters: 1909
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: DiCaprio
# endElement: 'ACTNOM'
#
# Characters: Leonardo
# endElement: 'ACTPNOM'
#
# Characters: 1974
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Winslet
# endElement: 'ACTNOM'
#
# Characters: Kate
# endElement: 'ACTPNOM'
#
# Characters: 1975
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Besson
# endElement: 'ACTNOM'
#
# Characters: Luc
# endElement: 'ACTPNOM'
#
# Characters: 1959
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Jovovich
# endElement: 'ACTNOM'
#
# Characters: Milla
# endElement: 'ACTPNOM'
#
# Characters: 1975
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Dunaway
# endElement: 'ACTNOM'
#
# Characters: Fane
# endElement: 'ACTPNOM'
#
# Characters: 1941
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Malkovitch
# endElement: 'ACTNOM'
#
# Characters: John
# endElement: 'ACTPNOM'
#
# Characters: 1953
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Karyo
# endElement: 'ACTNOM'
#
# Characters: Tchéky
# endElement: 'ACTPNOM'
#
# Characters: 1953
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Oldman
# endElement: 'ACTNOM'
#
# Characters: Gary
# endElement: 'ACTPNOM'
#
# Characters: 1958
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Holm
# endElement: 'ACTNOM'
#
# Characters: Ian
# endElement: 'ACTPNOM'
#
# Characters: 1931
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Portman
# endElement: 'ACTNOM'
#
# Characters: Natalie
# endElement: 'ACTPNOM'
#
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Parillaud
# endElement: 'ACTNOM'
#
# Characters: Anne
# endElement: 'ACTPNOM'
#
# Characters: 1960
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Anglade
# endElement: 'ACTNOM'
#
# Characters: Jean-Hughes
# endElement: 'ACTPNOM'
#
# Characters: 1955
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# Characters: Barr
# endElement: 'ACTNOM'
#
# Characters: Jean-Marc
# endElement: 'ACTPNOM'
#
# Characters: 1960
# endElement: 'ANNEENAISS'
#
# endElement: 'ARTISTE'
#
# Characters:
#
# endElement: 'FILMS'

# %% [markdown]
# ### Example 2: Get the titles

# %%
class GetTextInsideTag(xml.sax.ContentHandler):
    def __init__(self, tag = None):
        super().__init__()
        self.tag = tag
        self.reading = False
        self.buffer = []
        self.result = []
        

    def startElement(self, name, attrs):
        if not self.tag is None and name == self.tag:
            self.reading = True
        return


    def endElement(self, name):
        if self.buffer:
            # If something was read, then add it to results
            # before reseting the buffer
            self.result.append(' '.join(self.buffer))
        self.reading = False
        self.buffer = []
        return

    def characters(self, content):
        # When text is encountered
        # print("Characters '" + content + "'")
        if self.reading: self.buffer.append(content)
        return


tag = "TITRE"
handler = GetTextInsideTag(tag = tag)

path = "films.xml"
f = open(path)

xml.sax.parse(f, handler)

print(handler.result)
# Out:
# ['Vertigo', 'Alien', 'Titanic', 'Sacrifice', 'Volte/Face', 'Sleepy Hollow', 'American Beauty', 'Impitoyable', 'Gladiator', 'Blade Runner', 'Piège de cristal', '58 minutes pour vivre', 'Van Gogh', 'Seven', "L'armée des douze singes", 'Le nom de la rose', 'Pulp fiction', 'Mary à tout prix', 'Terminator', 'Les dents de la mer', 'Le silence des agneaux', "Le prince d'Egypte", 'Godzilla', 'Matrix', 'Mission: Impossible', 'Kagemusha', 'Les pleins pouvoirs', 'Le gendarme et les extra-terrestres', 'Les frères pétards', 'Le monde perdu', 'Rain Man', 'Top Gun', 'Les bronzés font du ski', 'MICROCOSMOS', 'Psychose', 'Le retour du Jedi', 'Les oiseaux', 'Reservoir dogs', 'Eyes Wide Shut', 'Shining', 'Pas de printemps pour Marnie', 'Fenêtre sur cour', 'La mort aux trousses', "Jeanne d'Arc", 'Le cinquième élément', 'Léon', 'Nikita', 'Le grand bleu']

# %% [markdown]
# ### Example 3: Get the titles of films staring some artist

# %%
class GetFilmsByArtistInCast(xml.sax.ContentHandler):
    def __init__(self, prenom, nom):
        super().__init__()
        self.prenomSearch = prenom
        self.nomSearch = nom

        self.result = []
        self.titleBuffer = []
        self.prenomBuffer = []
        self.nomBuffer = []

        self.titleTemp = None
        self.prenomTemp = None
        self.nomTemp = None
        
        self.whereInDoc = None

        self.reading = False
        

    def startElement(self, name, attrs):
        self.whereInDoc = name
        if name in ["PRENOM", "NOM", "TITRE"]:
            self.reading = True
        return

    def endElement(self, name):
        # If we read something that we need, then get the contentn and use it
        if name == "TITRE":
            self.titleTemp = ' '.join(self.titleBuffer)
            self.titleBuffer = []
        if name == "PRENOM":
            self.prenomTemp = ' '.join(self.prenomBuffer)
            self.prenomBuffer = []
        if name == "NOM":
            self.nomTemp = ' '.join(self.nomBuffer)
            self.nomBuffer = []

        # If we end reading a ROLE element, we can check if it contains the 
        # artist we want
        if name == "ROLE":
            if self.prenomSearch == self.prenomTemp and self.nomSearch == self.nomTemp:
                self.result.append(self.titleTemp)
        self.reading = False
        return

    def characters(self, content):
        if self.reading:
        # If we are in TITLE, we have to save it
            if self.whereInDoc == "TITRE": self.titleBuffer.append(content)
            if self.whereInDoc == "PRENOM": self.prenomBuffer.append(content)
            if self.whereInDoc == "NOM": self.nomBuffer.append(content)
        return

    def endDocument(self):
        self.titleBuffer = []
        self.prenomBuffer = []
        self.nomBuffer = []


prenom, nom = "Bruce", "Willis"
handler = GetFilmsByArtistInCast(prenom = prenom, nom = nom)

path = "films.xml"
f = open(path)

xml.sax.parse(f, handler)

print(handler.result)
# Out:
# ['Piège de cristal', '58 minutes pour vivre', "L'armée des douze singes", 'Pulp fiction', 'Le cinquième élément']

# %% [markdown]
# ### Ex 1: Queries with SAX on the movie dataset
#
# Try to do some other queries using SAX.
# Compare your results (and maybe even running times!) with other tools like XPath or DOM.
#
# I suggest the queries 1 to 8, and then query 11

# %% [markdown]
# ## Data science with text
#
# Here I want to introduce you to some more advanced topics in Data Science and Machine Learning.
#
# We will use it as an excuse to practice SAX
#
#
# ---
#
#
#
# **Bag of words and TF-IDF**
#
# In Data Science and Machine Learning, particularly in Natural Language Processing, the objects to study are text documents. There are different ways to study them, but from a mathematical perspective we need ways of encoding such text documents into more "vectorial" data
#
# The question becomes: ***How do you transform a piece of text into a vector to apply your algorithms on them?***
#
#
# One very common example is sentiment analysis. The basic idea is that you want to know if some text (for example a movie review or a tweet) is positive or negative towards a subject. This can be seen as a classification problem.
#
#
# The initial approach to turn a piece of text into a vector is the Bag of Words, where you characterize a document by the words that appear in it and their frequence. A more sophisticated approach can be TF-IDF that takes into account the number of words in each document and also the relative frequence of words across documents.
#
# See this site for a detailed and simple exmplanation if you have doubts
#
# https://www.analyticsvidhya.com/blog/2020/02/quick-introduction-bag-of-words-bow-tf-idf/
#
#
# In this excercise we will try to create such document vectors for our movie dataset using SAX as a way to read the data.

# %% [markdown]
# ### Bag of words
#
# We need to go through the document, get the RESUME and build a vocabulary that contains all the words present in all the RESUMEs.
#
# We do not care about every word. We will remove unecessary words using a special library
#
# We are going to optimize our code and create the bag of words as we go through the resumes

# %%
''' 2.1.1 
Write a function that given some text, it eliminates all non important words
and returns a list of words representing the text
We will use a library called spacy for the stop words in french and we can use
another library called gensim to help us do some other preprocessing

'''

import spacy
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
import gensim.parsing.preprocessing as prep
import re

CUSTOM_FILTERS = [lambda x: x.lower(), lambda x: re.sub('\W+',' ',x) ,\
                    prep.strip_tags, prep.strip_punctuation, \
                    prep.strip_multiple_whitespaces, \
                    prep.strip_numeric, \
                    prep.strip_short]
our_prep_func = lambda x: prep.preprocess_string(x, CUSTOM_FILTERS)


# Traiter le texte
resume = "Pulp Fiction décrit l'odyssée sanglante et burlesque de petits malfrats \
dans la jungle de Hollywood, ou s'entrecroisent les destins de deux petits \
tueurs, d'un dangereux gangster marié à une camée, d'un boxeur roublard, de \
prêteurs sur gages sadiques, d'un caïd élégant et dévoué, d'un dealer bon \
mari et de deux tourtereaux à la gachette facile..."

# Lets test the two approaches to see the difference
new = [s for s in resume.split() if s not in fr_stop]
print(new)

new = [s for s in our_prep_func(resume) if s not in fr_stop]
print(new)


# This is the actual function
def process_text(text, processing, stopwords = fr_stop):
    return [s for s in processing(text) if s not in stopwords]


print("Our final function")
new = process_text(resume, our_prep_func, fr_stop)
print(new)
# Out:
# ['Pulp', 'Fiction', 'décrit', "l'odyssée", 'sanglante', 'burlesque', 'petits', 'malfrats', 'jungle', 'Hollywood,', "s'entrecroisent", 'destins', 'petits', 'tueurs,', "d'un", 'dangereux', 'gangster', 'marié', 'camée,', "d'un", 'boxeur', 'roublard,', 'prêteurs', 'gages', 'sadiques,', "d'un", 'caïd', 'élégant', 'dévoué,', "d'un", 'dealer', 'bon', 'mari', 'tourtereaux', 'gachette', 'facile...']
# ['pulp', 'fiction', 'décrit', 'odyssée', 'sanglante', 'burlesque', 'petits', 'malfrats', 'jungle', 'hollywood', 'entrecroisent', 'destins', 'petits', 'tueurs', 'dangereux', 'gangster', 'marié', 'camée', 'boxeur', 'roublard', 'prêteurs', 'gages', 'sadiques', 'caïd', 'élégant', 'dévoué', 'dealer', 'bon', 'mari', 'tourtereaux', 'gachette', 'facile']
# Our final function
# ['pulp', 'fiction', 'décrit', 'odyssée', 'sanglante', 'burlesque', 'petits', 'malfrats', 'jungle', 'hollywood', 'entrecroisent', 'destins', 'petits', 'tueurs', 'dangereux', 'gangster', 'marié', 'camée', 'boxeur', 'roublard', 'prêteurs', 'gages', 'sadiques', 'caïd', 'élégant', 'dévoué', 'dealer', 'bon', 'mari', 'tourtereaux', 'gachette', 'facile']

# %%
''' 2.1.2
Defining the word count of a document
Write a function that given a list of words and a vocabulary, computes the word
count representation of the text
The vocabulary will be represented as a dictionary containing pairs (word, index)
where index is the position of the word in the vocabulary

We will suppose that all the words are in the vocabulary
'''

def bag_of_words(tokens, vocab):
    ''' Your code here '''
    return 


# Test it with a simple example
tokens = ["test", "sentence", "test", "test", "horse", "sentence"]
vocab = {"sentence":0, "horse":1, "test":2}
bow = bag_of_words(tokens, vocab)
print(bow)
# Out:
# None

# %%
''' 2.1.3
Expanding a vocabulary
When we read new text, some new words might appear. We need to add them to the
vocabulary we are considering.
Write a function that given a vocabulary and some new text (already preprocessed),
adds the new words to the vocabulary (if there are new words)
'''

def expand_vocab(vocab, new_tokens):
    ''' Your code here '''
    return 


# Test
tokens = ["test", "new_word", "horse", "more_novelty"]
vocab = {"sentence":0, "horse":1, "test":2}
expand_vocab(vocab, tokens)
print(vocab)
# Out:
# {'sentence': 0, 'horse': 1, 'test': 2}

# %%
''' 2.1.4
Put it all together
Now use the functions we created and SAX to build the bag of words representation
for all the resumes

Note: For the tests, use this dummy dataset so that we can see something
    https://universitedauphine-my.sharepoint.com/:u:/g/personal/lucas_gnecco-heredia_universitedauphine_onmicrosoft_com/EV8zxLKQpo5NgV4KUoOllWUBXgBWAOuZoq-OjIBTEsc_YQ?e=dMk2td

Note: We will take care of the length of the vectors later
'''

class ResumeBagOfWordsSax(xml.sax.ContentHandler):
    def __init__(self):
        super().__init__()
        self.vectors = {}
        self.vocab = {}
        
    def startElement(self, name, attrs):
        return 

    def endElement(self, name):
        return

    def characters(self, content):
        return



handler = ResumeBagOfWordsSax()

# %%
# Download the dummy file
# !wget "https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/imdb_simple_example.xml"
# Out:
# --2022-02-22 10:34:51--  https://raw.githubusercontent.com/lucasgneccoh/BDSS_Dauphine/main/data/imdb_simple_example.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1219 (1,2K) [text/plain]
# Saving to: ‘imdb_simple_example.xml’
#
# imdb_simple_example 100%[===================>]   1,19K  --.-KB/s    in 0s
#
# 2022-02-22 10:34:51 (34,7 MB/s) - ‘imdb_simple_example.xml’ saved [1219/1219]

# %%
path = "imdb_simple_example.xml"
f = open(path)

xml.sax.parse(f, handler)

print(*handler.vectors.items(), sep="\n")

# %%
'''
Lets fill the vectors with zeros to get them to the right length
'''
N = len(handler.vocab)
for k, v in handler.vectors.items():
    v += [0]*(N-len(v))

print("New vectors after resize")
print(*handler.vectors.items(), sep="\n")
# Out:
# New vectors after resize

# %%
''' 
We can create a table to better understand each vector

NOTE: This only makes sense with dummy datasets
'''

import pandas as pd
data = pd.DataFrame(data = handler.vectors, index = handler.vocab.keys())

data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### TF-IDF
# Now that we have the Bag of Words for each resume, we can create the TF-IDF representations
#
# This can be done in serveral ways, and you can try the one you think is more fun
#
#
#
# *   Use plain Python
# *   Use *numpy* (vectors, vector operations)
# *   Use *pandas* (easiest way IMO)
